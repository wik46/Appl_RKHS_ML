# %% [markdown]
# ### Hyperplanes over real and complex vector spaces
# Recall that given a vector space $X$ a hyper plane M is a affine linear subspace of codimension 1. We also know that M is a level set of some non-constant linear functional on $X$.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %% [markdown]
# ${\bf Example 1}$: Affine Hyperplanes in $\mathbb{R}^2$. We only need a linear functional and scalar c to describe a hyperplane. Recall that the Rietz-Representation theorem
# tells us that for every linear functional $\lambda $ on $H=\mathbb{R}^2$ there exists a unique vector $v\in \mathbb{R}^2$ such that $\lambda(x) = <x,v>$. Therefore is suffices to
# find a vector in $H$ and a scalar to describe the hyperplane.

# %%
# Creating data: Creates an np array from -5 to 5 with 100 points
n = 100
x = np.linspace(-5,5,1000)
y = np.linspace(-5,5,1000)
# Creating 
xx,yy = np.meshgrid(x,y)

# %%
#xx[0]

# %%
# This function will plot the hyperplane given a vector v=[a,b] and scalar c. It will return all the points on the hyperplane.
# Input: 2d vector as numpy array v and scalar c. And n is the size of the mesh here it is a 100
# Input: xx and yy mesh as above
def hyperplane_plotter(v,c,x):
    y = (-v[0]/v[1])*x+c/v[1]
    return y

# %%
# Determine Hyperplane
# Change v1 and c to change the hyperplane
v1 = np.array([-2,1]) #
c = 4


## Determining space
x = np.linspace(-5, 5, 100)
y = hyperplane_plotter(v1,c,x)


# Select length of axes and the space between tick labels
xmin, xmax, ymin, ymax = -5, 5, -5, 5
ticks_frequency = 1




# Plot 
fig, ax = plt.subplots(figsize=(10, 10))
# Plot the hyperplane
ax.plot(x, y, linewidth=2.0)
# Plot the vecotr that determines it
ax.scatter(v1[0], v1[1], c='green')
ax.plot([0, v1[0]], [0, v1[1]], c='green', lw=1.5, alpha=0.5)


# Set identical scales for both axes
ax.set(xlim=(xmin-1, xmax+1), ylim=(ymin-1, ymax+1), aspect='equal')

# Set bottom and left spines as x and y axes of coordinate system
ax.spines['bottom'].set_position('zero')
ax.spines['left'].set_position('zero')

# Remove top and right spines
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Create 'x' and 'y' labels placed at the end of the axes
ax.set_xlabel('x', size=14, labelpad=-24, x=1.03)
ax.set_ylabel('y', size=14, labelpad=-21, y=1.02, rotation=0)

# Create custom major ticks to determine position of tick labels
x_ticks = np.arange(xmin, xmax+1, ticks_frequency)
y_ticks = np.arange(ymin, ymax+1, ticks_frequency)
ax.set_xticks(x_ticks[x_ticks != 0])
ax.set_yticks(y_ticks[y_ticks != 0])

# Create minor ticks placed at each integer to enable drawing of minor grid
# lines: note that this has no effect in this example with ticks_frequency=1
ax.set_xticks(np.arange(xmin, xmax+1), minor=True)
ax.set_yticks(np.arange(ymin, ymax+1), minor=True)

# Draw major and minor grid lines
ax.grid(which='both', color='grey', linewidth=1, linestyle='-', alpha=0.2)

# Draw arrows
arrow_fmt = dict(markersize=4, color='black', clip_on=False)
ax.plot((1), (0), marker='>', transform=ax.get_yaxis_transform(), **arrow_fmt)
ax.plot((0), (1), marker='^', transform=ax.get_xaxis_transform(), **arrow_fmt)

plt.show()
